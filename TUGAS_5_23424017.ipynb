# %% [markdown]
# <a href="https://colab.research.google.com/github/khoirulanam61417-ux/PCD_KHOIRUL-ANAM_23424017/blob/main/TUGAS_5_23424017.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #*1.Low-pass filter*

# %%
from google.colab import files
import cv2
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
import io

# Pilih file dari komputer kamu
uploaded = files.upload()

# Mengambil nama file yang diupload dan membacanya
for filename in uploaded.keys():
    img_data = uploaded[filename]
    img = Image.open(io.BytesIO(img_data)).convert('L') # Ubah ke grayscale
    img = np.array(img)

print("Foto berhasil diupload!")
# Menggunakan Gaussian Blur sebagai LPF
# (15, 15) adalah ukuran kernel, semakin besar semakin blur
lpf_img = cv2.GaussianBlur(img, (15, 15), 0)

plt.imshow(lpf_img, cmap='gray')
plt.title("Hasil Low-Pass Filter")
plt.show()
# Out:
#      <input type="file" id="files-bc7eba96-143a-4a17-b9ed-8e5de3b48a2f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bc7eba96-143a-4a17-b9ed-8e5de3b48a2f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #*2.High-pass filter*

# %%
from google.colab import files
import cv2
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
import io

# Pilih file dari komputer kamu
uploaded = files.upload()

# Mengambil nama file yang diupload dan membacanya
for filename in uploaded.keys():
    img_data = uploaded[filename]
    img = Image.open(io.BytesIO(img_data)).convert('L') # Ubah ke grayscale
    img = np.array(img)

print("Foto berhasil diupload!")
# HPF menggunakan Laplacian
hpf_hasil = cv2.Laplacian(img, cv2.CV_64F)

plt.subplot(121), plt.imshow(img, cmap='gray'), plt.title('Original')
plt.subplot(122), plt.imshow(hpf_hasil, cmap='gray'), plt.title('High-Pass Filter')
plt.show()
# Out:
#      <input type="file" id="files-fc107efa-6faf-440f-b5f4-1d44e636e86e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fc107efa-6faf-440f-b5f4-1d44e636e86e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #*3. Band-pass filter*

# %%
from google.colab import files
import cv2
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
import io

# Pilih file dari komputer kamu
uploaded = files.upload()

# Mengambil nama file yang diupload dan membacanya
for filename in uploaded.keys():
    img_data = uploaded[filename]
    img = Image.open(io.BytesIO(img_data)).convert('L') # Ubah ke grayscale
    img = np.array(img)

print("Foto berhasil diupload!")
# BPF menggunakan selisih dua Gaussian Blur (Difference of Gaussians)
blur1 = cv2.GaussianBlur(img, (5, 5), 0)
blur2 = cv2.GaussianBlur(img, (25, 25), 0)
bpf_hasil = blur1 - blur2

plt.subplot(121), plt.imshow(img, cmap='gray'), plt.title('Original')
plt.subplot(122), plt.imshow(bpf_hasil, cmap='gray'), plt.title('Band-Pass Filter')
plt.show()
# Out:
#      <input type="file" id="files-d9943280-49e8-4f9e-a343-eeaf65c537fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d9943280-49e8-4f9e-a343-eeaf65c537fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #4. Referensi Judul Jurnal
# Berikut adalah beberapa referensi jurnal yang relevan dengan penggunaan filter dalam pengolahan citra:
#
# Judul: Implementasi Low Pass Filter Dan High Pass Filter Menggunakan Metode Konvolusi Pada Citra Digital
#
# Penulis: S. J. P. G. T. Anggo, A. H. Kridalaksana, & N. Puspitasari
#
# Tahun: 2018
#
# Fokus: Membandingkan efek penghalusan (blurring) dan penajaman tepi pada citra.
#
# Judul: Analisis Perbandingan Filter Gaussian, Mean dan Median Terhadap Reduksi Noise Pada Citra Digital
#
# Penulis: D. Putra & G. W. Wiguna
#
# Tahun: 2020
#
# Fokus: Penggunaan berbagai jenis Low-Pass Filter untuk membersihkan gangguan (noise) pada gambar.
#
# Judul: Aplication of Band-Pass Filter for Enhancing Medical Imaging Contrast
#
# Penulis: R. Kumar & S. Gupta
#
# Tahun: 2019
#
# Fokus: Penggunaan Band-Pass Filter untuk meningkatkan kontras pada hasil rontgen atau MRI agar diagnosa lebih akurat.
#
# Judul: Edge Detection using High Pass Filtering in Satellite Imagery
#
# Penulis: M. Abdullah & H. Farooq
#
# Tahun: 2021
#
# Fokus: Teknik High-Pass Filter untuk memetakan batas wilayah atau jalan pada foto satelit.
